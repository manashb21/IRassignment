# %%
import pandas as pd
import string
import math 

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("publications_data.csv")
len(df)
# Out:
# 17524

# %%
df = df.dropna()

# %%
one_word_titles = df[df['doc_title'].str.count('\s') == 0]['doc_title']
one_word_titles
# Out:
# 180               Cut-up
# 265         Introduction
# 266         Introduction
# 667             Religion
# 679             Religion
#               ...
# 16338    auto-invitation
# 16634               Lash
# 16981         Assessment
# 17164              Ghana
# 17265       Introduction
# Name: doc_title, Length: 129, dtype: object

# %%
df = df[~df['doc_title'].isin(one_word_titles)]

# %%
len(df)
# Out:
# 16712

# %%
ids = []
for i in range(1, len(df)+1):
    ids.append(i)

# %%
df['doc_id'] = ids

# %%
df
# Out:
#                  name                       job_title  \
# 0      Mohammed Ahmed  Lecturer in Project Management
# 1      Mohammed Ahmed  Lecturer in Project Management
# 2      Mohammed Ahmed  Lecturer in Project Management
# 3      Mohammed Ahmed  Lecturer in Project Management
# 4      Mohammed Ahmed  Lecturer in Project Management
# ...               ...                             ...
# 17519    Jackie Abell    Associate Professor Research
# 17520    Jackie Abell    Associate Professor Research
# 17521    Jackie Abell    Associate Professor Research
# 17522    Jackie Abell    Associate Professor Research
# 17523    Jackie Abell    Associate Professor Research
#
#                                        organization  \
# 0                 School of Strategy and Leadership
# 1                 School of Strategy and Leadership
# 2                 School of Strategy and Leadership
# 3                 School of Strategy and Leadership
# 4                 School of Strategy and Leadership
# ...                                             ...
# 17519  Centre for Agroecology, Water and Resilience
# 17520  Centre for Agroecology, Water and Resilience
# 17521  Centre for Agroecology, Water and Resilience
# 17522  Centre for Agroecology, Water and Resilience
# 17523  Centre for Agroecology, Water and Resilience
#
#                                                 doc_link  \
# 0      https://pureportal.coventry.ac.uk/en/publicati...
# 1      https://pureportal.coventry.ac.uk/en/publicati...
# 2      https://pureportal.coventry.ac.uk/en/publicati...
# 3      https://pureportal.coventry.ac.uk/en/publicati...
# 4      https://pureportal.coventry.ac.uk/en/publicati...
# ...                                                  ...
# 17519  https://pureportal.coventry.ac.uk/en/publicati...
# 17520  https://pureportal.coventry.ac.uk/en/publicati...
# 17521  https://pureportal.coventry.ac.uk/en/publicati...
# 17522  https://pureportal.coventry.ac.uk/en/publicati...
# 17523  https://pureportal.coventry.ac.uk/en/publicati...
#
#                                                doc_title  doc_id
# 0      Autonomous Vehicle and its Adoption: Challenge...       1
# 1      Predicting the Public Adoption of Connected an...       2
# 2      Investigating the Effect of Mass Variation for...       3
# 3      A new method towards achieving FES-induced mov...       4
# 4      Restoration of Movement using FES: An Introduc...       5
# ...                                                  ...     ...
# 17519  Mad Cows & British Politicians: The Role of Sc...   16708
# 17520  Broadcasting the royal role: Constructing cult...   16709
# 17521          The Discursive (Re)Construction of Events   16710
# 17522  I take full responsibility, I take some respon...   16711
# 17523  On the context dependence of national stereoty...   16712
#
# [16712 rows x 6 columns]

# %%
doc_sep = df.loc[:,['doc_id','doc_title']]

# %%
doc_sep.head()
# Out:
#    doc_id                                          doc_title
# 0       1  Autonomous Vehicle and its Adoption: Challenge...
# 1       2  Predicting the Public Adoption of Connected an...
# 2       3  Investigating the Effect of Mass Variation for...
# 3       4  A new method towards achieving FES-induced mov...
# 4       5  Restoration of Movement using FES: An Introduc...

# %%
doc_id_list = list(doc_sep['doc_id'])
doc_title_list = list(doc_sep['doc_title'])

corpus_dict = {doc_id_list[i] : doc_title_list[i] for i in range(len(doc_sep))}

# %%
corpus_dict
# Out:
# {1: 'Autonomous Vehicle and its Adoption: Challenges, Opportunities, and Future Implications',
#  2: 'Predicting the Public Adoption of Connected and Autonomous Vehicles',
#  3: 'Investigating the Effect of Mass Variation for Sliding Mode Control of Functional Electrical Stimulation Aided Sit-to-Stand in Paraplegia',
#  4: 'A new method towards achieving FES-induced movement',
#  5: 'Restoration of Movement using FES: An Introductory Study I',
#  6: 'Kinematic modelling of FES induced sit-to-stand movement in Paraplegia',
#  7: 'SMC scheme for FES aided restoration of STS movement in paraplegics',
#  8: 'Evolution of intelligent and nonlinear control approaches for FES induced movement generation of the lower limb',
#  9: 'New Concept for FES-Induced Movements',
#  10: 'Assessing the Use of Gold as a Zero-Beta Asset in Empirical Asset Pricing: Application to the US Equity Market',
#  11: 'Cross-Layer Multipath Multichannel MAC protocol for MANETs',
#  12: 'Performance evaluation of Receiver Directed Transmission protocol with a single transceiver in MANETs',
#  13: 'Reliable Multipath Multi-channel Route Migration over Multi Link-Failure in Wireless Ad Hoc Networks',
#  14: 'Resisting blackhole attacks on MANETs',
#  15: 'Dynamic Source Routing under Attacks',
#  16: 'AODV & SAODV under Attack: Performance Comparison',
#  17: 'AODV Routing Protocol Performance Analysis under MANET Attacks',
#  18: 'Resisting flooding attacks on AODV',
#  19: 'Analysis of security attacks on AODV routing',
#  20: 'Analysis and Evaluations of Wireless LANs Security Protocols',
#  21: 'An Active Attack on Token-Based Security Protocol',
#  22: 'A New Attack on Aziz-Diffie Security Protocol',
#  23: 'Social Impacts of a Mega-Dam Project as Perceived by Local, Resettled and Displaced Communities: A Case Study of Merowe Dam, Sudan',
#  24: 'Economic Contributions of Mega-Dam Infrastructure as Perceived by Local and Displaced Communities: A Case Study of Merowe Dam, Sudan',
#  25: 'Stock Liquidity and SMEs’ Likelihood of Bankruptcy: Evidence from the US Market',
#  26: 'Personalisation of power, neoliberalism and the production of corruption',
#  27: 'Corporate hedging and the cost of equity capital',
#  28: 'Is corporate hedging always beneficial? A theoretical and empirical analysis',
#  29: 'Stock Price and Volume Effects Associated with Changes in the Composition of the FTSE Bursa Malaysian KLCI',
#  30: 'Assessing Plastic Circular Economy Policies and the Use of Digital Technology in Africa',
#  31: 'Understanding Public Sentiment in Relation to the African Continental Free Trade Agreement',
#  32: 'Do lockdown and testing help in curbing COVID-19 transmission?',
#  33: 'Impact of Dynamic Traffic on Vehicle-to-Vehicle Visible Light Communication Systems',
#  34: 'Performance Evaluation of NRZ-OOK and Carrier-Less Amplitude Phase Modulation in Li-Fi Environment',
#  35: 'Scalar Minimax Filter-based Phase Tracking for Continuous-Variable Quantum Key Distribution',
#  36: 'Impact of Vehicle Headlights Radiation Pattern on Dynamic Vehicular VLC Channel',
#  37: 'Statistical channel modelling of dynamic vehicular visible light communication system',
#  38: 'Vehicular Visible Light Positioning using Receiver Diversity with Machine Learning',
#  39: 'LDPC-Coded CAP with Spatial Diversity for UVLC Systems over Generalized-Gamma Fading Channel',
#  40: 'Outdoor Visible Light Positioning Using Artificial Neural Networks for Autonomous Vehicle Application',
#  41: 'Emotional eating among adults with healthy weight, overweight and obesity: a systematic review and meta‐analysis',
#  42: 'Performance of Spatial Diversity DCO-OFDM in a Weak Turbulence Underwater Visible Light Communication Channel',
#  43: '"Is it time to throw out the weighing scales?" Implicit weight bias among healthcare professionals working in bariatric surgery services and their attitude towards non-weight focused approaches',
#  44: 'Precision Indoor Three-Dimensional Visible Light Positioning Using Receiver Diversity and Multilayer Perceptron Neural Network',
#  45: 'Variation and outcomes of liver-reducing dietary regimens before bariatric surgery: a national retrospective cohort study',
#  46: 'The Statistical Temporal Properties of Vehicular Visible Light Communication Channel',
#  47: 'Global variations in preoperative practices concerning patients seeking primary bariatric and metabolic surgery (PACT Study): A survey of 634 bariatric healthcare professionals',
#  48: '对数正态分布衰落下的光OFDM 水下可见光通信空间分集系统',
#  49: 'Managing idiopathic intracranial hypertension in pregnancy: practical advice',
#  50: 'Indoor Intruder Tracking Using Visible Light Communications',
#  51: 'Risk of Harm from Use of Sodium-Glucose Co-Transporter-2 (SGLT-2) Inhibitors in Patients Pre or Post Bariatric Surgery',
#  52: 'Optical spatial diversity for FSO communications',
#  53: 'The impact of patient anxiety on intragastric balloon (IGB) insertion procedure: a mixed-methods study',
#  54: 'Regular-Shaped Geometry-Based Stochastic Model for Vehicle-to-Vehicle Visible Light Communication Channel',
#  55: "Efficacy of pre-operative'liver shrinking'dietary regimens: a UK national cohort study",
#  56: 'Reducing Noise Pollution of Emergency Vehicle Sirens with an Early Warning System',
#  57: 'Experiences and perceptions of dietitians for obesity management: a general practice qualitative study',
#  58: 'Group versus one-to-one multi-component lifestyle interventions for weight management: a systematic review and meta-analysis of randomised controlled trials',
#  59: 'Scattering regimes for underwater optical wireless communications using Monte Carlo simulation',
#  60: 'Demonstration of a multi-hop underwater visible light communication system',
#  61: 'Post-bariatric surgery nutritional follow-up in primary care: a population-based cohort study',
#  62: 'Design of a visible light communication system for deep sea divers based on analogue frequency modulation',
#  63: 'Socio‐demographic predictors of uptake of a virtual group weight management program during the COVID‐19 pandemic',
#  64: 'Developing Integrated Clinical Pathways for the Management of Clinically Severe Adult Obesity: a Critique of NHS England Policy',
#  65: 'Weight loss during medical weight management does not predict weight loss after bariatric surgery: a retrospective cohort study',
#  66: 'An Observational Study Comparing Levels Of Protein Intake After Gastric Banding, Sleeve Gastrectomy And Roux-En-Y Gastric Bypass Integrated Health',
#  67: 'Bariatric surgery among older adults: a matched case-control study on 30-day and 5-year mortality and changes in Body Mass Index and HbA1c up to 5-years post-operatively',
#  68: 'The relationship between relative deprivation and access to bariatric surgery',
#  69: 'A Systematic Review and Meta-Analysis of the Likelihood of Attaining at >5% Pre-Operative Weight Loss in Group- and Individually-Delivered Interventions.',
#  70: 'Binge eating disorder and night eating syndrome in adults with type 2 diabetes: a systematic review',
#  71: 'Preoperative weight loss with glucagon-like peptide-1 receptor agonist treatment predicts greater weight loss achieved by the combination of medical weight management and bariatric surgery in patients with type 2 diabetes: A longitudinal analysis',
#  72: 'The Effectiveness of Group versus Individual Lifestyle Interventions for Overweight and Obese Adults:  A Systematic Review and Meta-analysis of Randomised Controlled Trials',
#  73: 'The Protector Band: Outcomes Following The Use Of A Re-Engineered Adjustable Gastric Band',
#  74: 'The use of ketogenic diet in a patient with post-prandial hyperinsulinemic hypoglycaemia after m Roux-en-Y Gastric Bypass surgery: a case study',
#  75: 'Response to GLP-1 receptor agonist treatment pre-bariatric surgery does not predict post-surgery weight loss in patients with Type 2 diabetes: a retrospective study',
#  76: 'Short-term weight loss results In Western Europeans versus South Asian patients after laparoscopic adjustable gastric banding: a 1: 2 matched control cohort study',
#  77: 'The Prevalence and Impact of Trace Mineral Deficiencies following Bariatric Surgery: An Observational Cohort Study',
#  78: 'Effect of obesity on neutrophil function',
#  79: 'Corporate Political Activity and Bribery in Africa: Do Internet Penetration and Foreign Ownership Matter?',
#  80: 'Corporate Political Strategies in Weak Institutional Environments: A Break from Conventions',
#  81: 'Market in Financial Instruments Directive (MiFID), stock price informativeness and liquidity',
#  82: 'The effect of government involvement and payment method on merger and acquisition performance: the case of China',
#  83: 'The impact of regulations on compliance costs, risk-taking, and reporting quality of the EU banks',
#  84: 'Evaluation of merger premium and firm performance in Europe',
#  85: 'Digital Image Correlation for Measuring Full-Field Residual Stresses in Wire and Arc Additive Manufactured Components',
#  86: 'Effects of Process Variants on Residual Stresses in Wire Arc Additive Manufacturing of Aluminum Alloy 5183',
#  87: 'Influence of Deposition Strategies on Residual Stress in Wire + Arc Additive Manufactured Titanium Ti‐6Al‐4V',
#  88: 'INHALE pause Exhale',
#  89: 'An experimental study of residual stress and direction-dependence of fatigue crack growth behaviour in as-built and stress-relieved selective-laser-melted Ti6Al4V',
#  90: 'INHALE Pause EXHALE: DRAWING-IN-BREATHING-OUT.',
#  91: 'Evaluation of residual stresses induced by cold spraying of Ti-6Al-4V on Ti-6Al-4V substrates',
#  92: 'Fatigue crack growth in a laser shock peened residual stress field',
#  93: 'On Smoke and Fog: Performance Re-visioning, Remembrance and Reclamation',
#  94: 'Notes for a Performance – Weather Permitting',
#  95: 'Measurement and Modelling of Residual Stress in Wire-Feed Additively Manufactured Titanium',
#  96: 'Notes for a Performance – (Re) visioning a Smoky Meeting: Notes for a Performance – (Re) visioning a Smoky Meeting',
#  97: 'Made in Translation: Notes for a Performance – (Re) visioning a Ritual. Portico Library',
#  98: 'Prediction of residual stress within linear friction welds using a computationally efficient modelling approach',
#  99: 'Follow Un-Follow',
#  100: 'Between 1, 2 & 3',
#  101: 'Residual stress and texture control in Ti-6Al-4V wire + arc additively manufactured intersections by stress relief and rolling',
#  102: 'Residual Stress Evaluation in Selective-Laser-Melting Additively Manufactured Titanium (Ti-6Al-4V) and Inconel 718 using the Contour Method and Numerical Simulation',
#  103: 'Analysis of Residual Stresses in Laser-Shock-Peened and Shot-Peened Marine Steel Welds',
#  104: 'Minimization and Mitigation of Wire EDM Cutting Errors in the Application of the Contour Method of Residual Stress Measurement',
#  105: 'Effect of ultrasonic peening and accelerated corrosion exposure on the residual stress distribution in welded marine steel',
#  106: 'Fatigue performance of friction stir welded marine grade steel',
#  107: 'Surface preparation for residual stress measurement of an accelerated corrosion tested welded marine steel',
#  108: 'The effect of compressive fatigue loads on fatigue strength of non-load carrying specimens subjected to ultrasonic impact treatment',
#  109: 'The effect of laser shock peening on hardness and microstructure in a welded marine steel',
#  110: 'Effect of Ultrasonic Peening on Fatigue Strength of Welded Marine Structures - Lloyd’s Register Research Programme',
#  111: 'Residual Stresses in Ultrasonically Peened Fillet Welded Joints',
#  112: 'Residual Stress Measurements and Fatigue Testing of Butt Welds Subjected to Peening Treatments',
#  113: 'Modelling the impact of non-pharmaceutical interventions on COVID-19 exposure in closed-environments using agent-based modelling',
#  114: 'Agent-Based Heuristics Model for Measuring Customer Disruption Impact on Production and Inventory Replenishment',
#  115: 'Agent-Based Modelling and Heuristic Approach for Solving Complex OEM Flow-Shop Productions under Customer Disruptions',
#  116: 'Developing an Agent Based Heuristic Optimisation System for Complex Flow Shops with Customer-Imposed Production Disruptions',
#  117: 'Agent Based Model for Complex Flow Shop Manufacturing Systems with Customer-Related Production Disruptions',
#  118: 'Applying the utility index to review single best answer questions in medical education assessment',
#  119: 'Approach-achievement goals and motivational context on psycho-physiological functioning and performance among novice basketball players',
#  120: 'Motivational processes in the coach-athlete relationship: A multi-cultural self-determination approach',
#  121: 'The effects of learning imagery under different motivational conditions on the psychomotor performance and well-being of novice dart-throwers: A self-determination perspective.',
#  122: "Applying the TCTSA to explore athletes' temporal approach to performance",
#  123: '4. Governance Models and Structures',
#  124: 'Perceptions of the peer-climate, self-motivation, and indices of well- and ill-being among UG students',
#  125: 'Feeding forward from summative assessment: The Essay Feedback Checklist as a learning tool',
#  126: '6. Governance Self-Assessment, External Criteria, and Maintenance',
#  127: 'Psychological effects of injury severity in team-sports',
#  128: 'The well- and ill-being of participants in competitive sport settings: A review of motivational determinants',
#  129: '7. Conclusion',
#  130: 'Evaluating sport psychology teaching through action research',
#  131: 'Perceived coach-autonomy support, basic need satisfaction and the well- and ill-being of elite youth soccer players: A longitudinal investigation',
#  132: 'Books Contain Multitudes: Exploring Experimental Publishing (2022 update)',
#  133: 'London’s Off-Site Manufactured Housing Model as a Practical Solution to Change the Future of High Density Cities: A Feasibility Study to Implement it in Baghdad, Al-Sadr City',
#  134: 'The daily role of basic psychological needs and well-being in an elite youth soccer environment: A self-determination approach',
#  135: 'Perceptions of the teaching environment, engagement and burnout among university students on a sports-related degree programme in the UK',
#  136: 'Open Book Collective: Our Organisational Model',
#  137: 'Benefits and Challenges of Implementing Six Sigma: “As a Process Improvement Management Strategy”',
#  138: 'Causes of time overruns in the construction industry in Egypt',
#  139: 'Achievement goals, competition appraisals, and the well- and ill-being of elite youth soccer players over two competitive seasons',
#  140: 'Meta-Perceptions of the Coach-Athlete Relationship, Achievement Goals, and Intrinsic Motivation Among Sport Participants',
#  141: 'Open Book Collective: A Model for Open Community-led Governance',
#  142: 'Challenges and Barriers to Women in the UK Construction Industry',
#  143: 'Construction industry and women: a Review of the barriers,',
#  144: 'Achievement goals, competition appraisals, and the psychological and emotional welfare of sport participants',
#  145: 'Autonomy support, basic need satisfaction and the optimal functioning of adult male and female sport participants: A test of basic needs theory',
#  146: 'Part 1: Mapping & Situating Experimental Books',
#  147: 'Effectiveness of the Modern Methods of Construction in Terms of Cost and Time: A Case Study of the United Kingdom',
#  148: 'Exploring the Impact of Implementing Building Information Modelling to Support Sustainable Development in the Lebanese Construction Industry: A Qualitative Approach',
#  149: 'Part 2: A Typology of Experimental Books',
#  150: 'Investigating the Benefits of BIM for Mid-Rise Timber Buildings in Canada: A Qualitative Study',
#  151: 'Modular Construction in the United Kingdom Housing Sector: Barriers and Implications',
#  152: 'Re-use and/as Re-writing',
#  153: 'Performance of Sustainable Building Fabric to Replace the Traditional Cavity Wall Technique for New Housing Sector in the UK',
#  154: 'Towards Better Practices for the Community Governance of Open Infrastructures',
#  155: 'Prefabrication as a Solution for Tackling the Building Crisis in the UK',
#  156: 'Sustainable Public Buildings Designed and Constructed in Wood',
#  157: 'Works cited',
#  158: 'The Effectiveness of using Modern Construction Methods as a Solution to Assist the Social Housing Shortage in the United Kingdom',
#  159: 'Books Contain Multitudes: Exploring Experimental Publishing',
#  160: 'The Impact Of Green Certification Breeam On Occupancy Rates Of Commercial Buildings In The UK',
#  161: 'Exploring Experimental Publishing',
#  162: 'Building Research Establishment Environmental Assessment Methodology on the UK Residential Projects',
#  163: 'Living Books: Experiments in the Posthumanities',
#  164: 'Part 1: Interaction in Context',
#  165: 'Part 2: Tools and Technologies',
#  166: 'Part 3: Recommendations, Guidelines, and Best Practices',
#  167: 'Promoting and Nurturing Interactions with Open Access Books: Strategies for Publishers and Authors (1.0). A COPIM WP6 Research and Scoping Report',
#  168: 'Scaling Small; Or How to Envision New Relationalities for Knowledge Production',
#  169: 'Versioning and Iterative Publishing',
#  170: 'Community-led Open Publication Infrastructures for Monographs (COPIM): Annual Report - Year 1 (2019-2020)',
#  171: 'Post It',
#  172: 'The Ethics Of Emergent Creativity: Can We Move Beyond Writing As Human Enterprise, Commodity And Innovation?',
#  173: 'Towards a Roadmap for Open Access Monographs',
#  174: 'Unruly Gestures: Seven Cine-Paragraphs on Reading/Writing Practices in our Post-Digital Condition',
#  175: 'Collectivity and collaboration: imagining new forms of communality to create resilience in scholar-led publishing',
#  176: 'Disrupting the Journal of Media Practice',
#  177: 'Performative Publications',
#  178: 'Performative Publications (designed postprint platform version)',
#  179: 'The Poethics of Openness',
#  180: 'Changing Publishing Ecologies. A Landscape Study of New University Presses and Academic-led Publishing',
#  181: 'Distributed, Radical And Resilient: Speculations On A Community-Led Future For Open Access Publishing',
#  182: 'Interview transcriptions: Changing Publishing Ecologies. A Landscape Study of New University Presses and Academic-led Publishing',
#  183: 'Performative Publications (full online interactive version)',
#  184: 'Modelling the impact of non-pharmaceutical interventions on COVID-19 exposure in closed-environments using agent-based modelling',
#  185: 'The Disrupted Journal of Media Practice',
#  186: 'Kinematic control of redundant robots with online handling of variable generalized hard constraints',
#  187: 'Human-robot contactless collaboration with mixed reality interface',
#  188: 'The Surge in New University Presses and Academic-Led Publishing: An Overview of a Changing Publishing Ecology in the UK',
#  189: 'Motion Control of Redundant Robots with Generalised Inequality Constraints',
#  190: 'Task Priority Matrix at the acceleration level: Collision avoidance under relaxed constraints',
#  191: 'Disrupting the Humanities: Towards Posthumanities Special Issue',
#  192: 'Task Priority Matrix Under Hard Joint Constraints',
#  193: 'Experiences in Safe Physical Human-Robot Interaction',
#  194: 'La Naturaleza Politica del Libro: Sobre Libros de Artista y Acceso Abierto Radical',
#  195: 'Stable torque optimization for redundant robots using a short preview',
#  196: 'Faster motion on Cartesian paths exploiting robot redundancy at the acceleration level',
#  197: 'Multi-sensor Control System for Safe Human-Robot Collaboration',
#  198: '\'Posthumanities: The Dark Side of "The Dark Side of the Digital"\'',
#  199: 'Really, We’re Helping To Build This . . . Business: The Academia.edu Files',
#  200: 'Fast Motion on Cartesian Paths by Exploiting Robot Redundancy at the Acceleration Level',
#  201: 'Visual coordination task for human-robot collaboration',
#  202: 'Cutting scholarship together/apart. Rethinking the political-economy of scholarly book publishing',
#  203: 'Publication practices in motion: The benefits of open access publishing for the humanities',
#  204: 'A project exploring open access monograph publishing in the Netherlands',
#  205: 'Practise what you preach: Engaging in humanities research through critical praxis',
#  206: 'Reviving the Undead Book',
#  207: "The political nature of the book: on artists' books and radical open access",
#  208: "Mettre en pratique ce que l'on prêche. La recherche en sciences humaines et sa praxis critique",
#  209: 'Digital Monographs in the Humanities and Social Sciences: Report on User Needs',
#  210: 'Overview of Open Access Models for eBooks in the Humanities and Social Sciences',
#  211: 'Does shared tenure between audit committee chair and engagement partner affect audit outcomes? Evidence from the UK',
#  212: 'Non‑executive employee ownership and financial reporting quality: evidence from Europe',
#  213: 'Fair value accounting and value relevance of equity book value and net income for European financial firms during the crisis',
#  214: 'Does Accounting Treatment of Share-Based Payments Impact Performance Measures for Banks?',
#  215: 'Share-Option Based Compensation Expense, Shareholder Returns and Financial Crisis',
#  216: 'A coupled drug kinetics-cell cycle model to analyse the response of human cells to intervention by topotecan',
#  217: 'A deterministic model for the sublayer streaks in turbulent boundary layers for application to flow control',
#  218: 'Modelling the control of cell proliferation by an anti-cancer agent',
#  219: 'A novel integrative bioinformatics environment for encoding and interrogating timelapse microscopy images',
#  220: 'A PK-PD model of cell cycle response to topotecan',
#  221: 'Control of cell proliferation by an anti-cancer agent: Modelling, Validation & Sensitivity',
#  222: 'Disturbance development in boundary layers over compliant surfaces',
#  223: 'Experimental verification of Type-II-eigenmode destabilization in the boundary layer over a compliant rotating disk',
#  224: 'Effects of wall compliance on the laminar-turbulent transition of torsional Couette flow',
#  225: 'Laminar-turbulent boundary-layer transition over a rough rotating disk',
#  226: 'An evaluation of the antimicrobial effects of phytochemical fractions from Prosopsis africana and Uvaria chamae against Staphylococcus aureus and Pseudomonas aeruginosa',
#  227: 'Antibiofilm activity of Prosopis africana and Uvaria chamae extracts against preformed biofilm of Clostridium difficile and Propionibacterium acnes strains',
#  228: 'Antimicrobial activity of selected herbal extracts against Propionibacterium acnes, the causative agent of skin acne lesions',
#  229: 'Is there a role for the bacterial suicide response in antibiotic sensitivity testing?',
#  230: 'Growth-phase related sensitivity to antibiotics; implications for therapy?',
#  231: 'Microflora diversity in raw ewes’ milk cheese: from raw material to finished product',
#  232: 'Metabolomic Response of Escherichia coli to Environmental Change',
#  233: 'Determination of the pathways involved in free radical production during sub-lethal injury',
#  234: 'Microbiological load of pork during slaughter',
#  235: 'The epidemiology of Escherichia coli in the pork abattoir',
#  236: 'Stressed bacteria: a role for free radicals?',
#  237: 'A competitive microflora increases the resistance of Salmonella typhimurium to inimical processes: evidence for a suicide response',
#  238: 'Acceleration of RpoS in Salmonella typhimurium by a competitive microflora is not due to starvation',
#  239: 'Effect of reduced water activity on RpoS in Salmonella typhimurium modelled using bioluminescence',
#  240: 'Effect of total microbial load on intracellular RpoS levels of Salmonella typhimurium and the implications for axenic culture modelling',
#  241: 'The importance of heterogeneous populations: implications for predictive microbiology',
#  242: 'Use of bioluminescence to model the effect of a competitive microflora on the level of RpoS in Salmonella',
#  243: 'A novel method for the growth of bacterial films in vitro',
#  244: 'A culture system to produce surface films with oral bacteria',
#  245: 'Does shared tenure between audit committee chair and engagement partner affect audit outcomes? Evidence from the UK',
#  246: 'Audit committees’ oversight role in developing countries: evidence from Jordan',
#  247: 'Does state ownership affect R&D investments? Evidence from China',
#  248: 'Do Tenure and Age of Board Chair Matter for R&D Investment?',
#  249: 'Audit Committee and Audit Quality: An Empirical Analysis Considering Industry Expertise, Legal Expertise and Gender Diversity',
#  250: 'Ownership structure and audit quality: An empirical analysis considering ownership types in Jordan',
#  251: 'Corporate Governance and Audit Quality: Further Recommendations Beyond the Code',
#  252: 'Corporate Governance Practices in Jordan',
#  253: 'QoS within Business Grid Quality of Service (BGQoS)',
#  254: 'High level QoS-driven model for Grid applications in a simulated environment',
#  255: 'An extension of GridSim for quality of service',
#  256: 'Hacking the Museum: Mandela27 - A Democratic DIY Pop-Up Installation',
#  257: 'Using narrative conventions to analyse travel stories',
#  258: 'Singular Asynchronous Writing Tutorials: A Pedagogy of Text-Bound Dialogue',
#  259: 'A Heterogeneous Identity: The Case of the Etruscans',
#  260: 'Multi-point Angle of Attack Sensing for Avoidance of Loss of Control in Flight',
#  261: 'An instructive algorithm for aircraft elevator sizing to be used in preliminary aircraft design software',
#  262: 'Employing control surface model in preliminary aircraft design software.',
#  263: 'Environmental Impact of High Altitudes on the Operation of PEM Fuel Cell Based UAS',
#  264: 'Experimental Testing and Validation of the Mathematical Model for a Self-Humidifying PEM Fuel Cell',
#  265: 'Programmable Aileron Sizing Algorithm for Use in Preliminary Aircraft Design Software',
#  266: 'Delivery of Aircraft Design Curriculum through Problem-Based Learning Approach',
#  267: 'Simplified mathematical model of proton exchange membrane fuel cell based on horizon fuel cell stack',
#  268: 'Anti-Venin delivery system using a Low cost UAS',
#  269: 'A Comparative Study of Cost Estimation Models used For Preliminary Aircraft Design',
#  270: 'Transport Aircraft Weight Estimation as a Function of Range and Number of Passengers',
#  271: 'Modelling and Examining Open Circuit Voltage for PEM Fuel Cells',
#  272: 'Simulation model for mesophilic anaerobic digestion heating system',
#  273: "Callimachus' Epigram Theatre",
#  274: 'Early Writing Metaphors in Performance',
#  275: "Measuring Up: The Greek Analogies Behind Vitruvius' Geometry of the Body",
#  276: 'Review of Deborah Tarn Steiner, Choral constructions in Greek culture: the idea of the chorus in the poetry, art and social practices of the Archaic and early Classical period. Cambridge; New York: Cambridge University Press, 2021. Pp. 761. ISBN 9781107110687 £75,00.',
#  277: 'An Unnoticed Pun in Hipponax fr. 3a W. = 2 D.',
#  278: 'Review of Eric Csapo, Peter Wilson, A social and economic history of the theatre to 300 BC. Vol. II. Theatre beyond Athens: documents with translation and commentary. Cambridge: Cambridge University Press, 2020. Pp. xix, 939. ISBN 9780521765572 $200.00.',
#  279: 'Semantic Satiation for Poetic Effect',
#  280: 'Crates, Playwright of Old Comedy: Perrone (S.) Cratete. Introduzione, Traduzione e Commento. (Fragmenta Comica 2.) Pp. 277. Göttingen: Verlag Antike, 2019. Cased, €64.99. ISBN: 978-3-946317-47-0.',
#  281: 'Fragments of Greek Tragedy: Wright (M.) The Lost Plays of Greek Tragedy. Volume 1: Neglected Authors. Pp. xxx + 277. London and New York: Bloomsbury Academic, 2016. Paper, £21.99 (Cased, £85). ISBN: 978-1-4725-6775-8 (978-1-4725-6776-5 hbk). Wright (M.) The Lost Plays of Greek Tragedy. Volume 2: Aeschylus, Sophocles and Euripides. Pp. xii + 308. London and New York: Bloomsbury Academic, 2019. Paper, £19.99, US$26.95 (Cased, £65, US$88). ISBN: 978-1-4742-7647-4 (978-1-4742-7646-7 hbk).',
#  282: 'Species of Ambiguity in Semonides Fr. 7',
#  283: "Location and Motif in Meleager's Coronis (A.P. 12.257)",
#  284: 'Oil Spill Modeling for the Mariner Oil Field, East of Shetland, United Kingdom, North Sea',
#  285: 'Professional Development of a Production & Facilities Generalist as a Jack-of-All-Trades',
#  286: 'An Analysis of the Fate and Trajectory Simulation of Bonny Light Crude From The Dangote Single Point Mooring(SPM) Terminal Off the South Atlantic Ocean, Lagos Nigeria',
#  287: 'Forecasting system for predicting the dynamics of oil spill in a tide-dominated estuary',
#  288: 'Influence of projected climatic conditions and varying lateral points of release on oil slick transport in a tide-dominated estuary',
#  289: 'Numerical Modelling of Oil Spill Transport in Tide-Dominated Estuaries: A Case Study of Humber Estuary, UK',
#  290: 'Crude Oil and Natural Gas: Key to a Sustainable Energy Future',
#  291: 'Near-term impacts of climate variability and change on hydrological systems in West and Central Africa',
#  292: 'Poverty in Extractive Industries and Environmental Impact Assessment Process',
#  293: 'Interannual to Multi-decadal streamflow variability in West and Central Africa: Interactions with catchment properties and large-scale climate variability',
#  294: 'Oil facility operations: a multivariate analyses of water pollution parameters',
#  295: 'Trend and variability in a new, reconstructed streamflow dataset for West and Central Africa, and climatic interactions, 1950 – 2005',
#  296: 'A distributed, scalable and provenance-enabled data access protocol for spatial data infrastructure',
#  297: 'Integrated Ocean Observing Systems as a source of scientific information for supporting oil spill response: From Gulf of Mexico to Gulf of Guinea',
#  298: 'Oil Spill Trajectory Simulation for the Clair Oilfield, Faroe Shetland Channel, United Kingdom Continental Shelf',
#  299: 'Trend and variability in western and central Africa streamflow, and their relation to climate variability between 1950 and 2010',
#  300: 'Using a global ocean circulation model to conduct a preliminary risk assessment of oil spills in the Atlantic',
#  301: 'Application of analytic hierarchy process for analysis of impact significance in EIA of oil and gas industry',
#  302: 'A systematic quality assessment of Environmental Impact Statements in the oil and gas industry',
#  303: 'On the issue of Environmental Impact Statements’ quality in the Oil & Gas Industry',
#  304: 'Methane emissions from oil and gas transport facilities – exploring innovative ways to mitigate environmental consequences',
#  305: 'MetOcean Data, Oil Spill Response and Modelling in the Gulf of Guinea: Session 20 - Technical session',
#  306: 'Evaluating interdiction of oil pipelines at river crossings using environmental impact assessments',
#  307: 'Oil spill trajectory simulation for the Saltpond oilfield, Ghana, West Africa.',
#  308: 'Evaluation of methane (CH4) emissions from Oil and Gas transportation facilities: finding innovative ways to mitigate environmental consequences.',
#  309: 'Application of Flow Duration Analysis in River Oil Spill Management',
#  310: 'Attacks on oil transport pipelines in Nigeria: A quantitative exploration and possible explanation of observed patterns',
#  311: 'Assessing the Quality of Oil and Gas project EISs: A Preface',
#  312: 'Hydraulic exponent for predicting oil travel time in Rivers:  A case of pipeline river crossing',
#  313: 'Pipeline interdiction and bridging in Nigeria: is a modification to the spatial connectivity matrix model required?',
#  314: 'Predicting Oil Slick Migration at a Pipeline River Crossing on the River Niger Using Hydraulic Geometry',
#  315: 'International Business and People Relations',
#  316: 'A Guidebook for Identifying and Preventing Plagiarism for Academic Staff',
#  317: 'Urban environmental footprints of petroleum oil infrastructure in Lagos, Nigeria',
#  318: "The use of online media in classroom for enhancing students' learning experiences: Youtube, Socrative and Kahoot",
#  319: 'International Students in the UK',
#  320: 'My UK Teaching Experience - Teaching International Students',
#  321: "Transportation In Nigeria's Oil and Gas Industry: An Environmental Challenge",
#  322: 'The influence of Chinese entrepreneurs’ characteristics on guanxi networking',
#  323: 'The Investigation of Food Wastage in Chinese Universities - Taking the China Agricultural University as a Case',
#  324: 'A FEA simulation study on impeller failures considering various materials',
#  325: 'Investigation on CFRP 3D printing build parameters and their effect on topologically optimised complex models',
#  326: 'Processing and characterization of aluminium alloy 6061 graphene composite printed by direct metal laser sintering',
#  327: 'A digital twin study for immediate design / redesign of impellers and blades: Part 1: CAD modelling and tool path simulation',
#  328: 'A FEA simulation study of ball end mill for fixed 3+1 / 3+2 axis machining of Ti-6Al-4V',
#  329: 'Performance Evaluation of (ALCRN) PVD Coated CBN Inserts on Machining of Inconel 718',
#  330: 'An IoT based industry 4.0 architecture for integration of design and manufacturing systems',
#  331: 'A Circular Capability Framework to address food waste and losses in the agri-food supply chain: The antecedents, principles and outcomes of Circular Economy',
#  332: 'Toolpath algorithm for free form irregular contoured walls/surfaces with internal deflecting connections',
#  333: 'A Cloud Based Feature Recognition System to Support Collaborative and Adaptive Process Planning',
#  334: 'Regulatory mood-congruence and herding: evidence from cannabis stocks',
#  335: 'A Shadowed Legal Transplantation: Takeover Defence Regulation in China',
#  336: 'FEM analysis to optimally design end mill cutters for milling of Ti-6Al-4V',
#  337: 'Automated design and STEP-NC machining of impellers',
#  338: 'Feedback Trading and the Ramadan Effect in Frontier Markets',
#  339: 'Online Social Networks, Media Supervision and Investment Efficiency: An Empirical Examination of Chinese Listed Firms',
#  340: 'Feature recognition & tool path generation for 5 axis step-nc machining of free form / irregular contoured surfaces',
#  341: 'Integration of cad/ tool path data for 5-axis step-nc machining of free form / irrregular contoured surfaces',
#  342: 'Ownership Structure, Information Asymmetry and Growth of the Firm: Implications from Non-Financial Firms Listed in S&P500',
#  343: 'The propensity to pay dividends: empirical evidence from the MENA region',
#  344: 'A STEP AP 203-214-based machinable volume identifier for identifying the finish-cut machinable volumes from rough-machined parts',
#  345: 'Development of a feature recognition module for tapered and curved base features',
#  346: 'Diversification Benefits of Shari’ah Compliant Equity ETFs in Emerging Markets',
#  347: 'Relative Reference Prices and M&A Misvaluations',
#  348: 'Understanding time-inconsistent heterogeneous preferences in economics and finance: A practice theory approach',
#  349: "Predicting Unlisted SMEs' Default: Incorporating Market Information on Accounting-based Models for Improved Accuracy",
#  350: 'Intraday Herding on a Cross-Border Exchange',
#  351: 'Ownership Structure and the Choice of SEO Issue Method in the UK',
#  352: 'Special issue of the Review of Behavioral Finance guest editors’ introduction',
#  353: 'Handbook of Frontier Markets: African, European and Asian Evidence',
#  354: 'Handbook of Frontier Markets: Evidence from Asia and International Comparative Studies',
#  355: 'Structural Breaks, Efficiency and Volatility: An Empirical Investigation of Southeast Asian Frontier Markets',
#  356: 'The Portfolio Diversification Benefits of Frontier Markets: An Investigation Into Regional Effects',
#  357: 'Impact of board independence on the quality of community disclosures in annual reports',
#  358: 'Paraconsistent games and the limits of rational self-interest',
#  359: 'On the impact of market mergers over herding: evidence from EURONEXT',
#  360: "Short-selling constraints and 'quantitative' investment strategies",
#  361: 'UK Short Selling Activity and Firm Performance',
#  362: 'Seasoned equity offerings, operating performance and overconfidence: Evidence from the UK',
#  363: "Size effect, methodological issues and 'risk-to-default': Evidence from the UK stock market",
#  364: 'Institutional Data Analysis and Machine Learning Prediction of Student Performance',
#  365: 'An Empirical Evaluation of Learning Style and Knowledge Level Adaptation',
#  366: 'Usability and Effectiveness Evaluation of Adaptivity in E-Learning Systems',
#  367: 'An E-Learning Investigation into Learning Style Adaptivity',
#  368: 'Design and Usability Evaluation of Adaptive e-learning Systems Based on Learner Knowledge and Learning Style',
#  369: "Students' Satisfaction in Learning Style-Based Adaptation",
#  370: 'The Impact of Learning Style Adaptivity in Teaching Computer Security',
#  371: 'Adaptivity in E-learning systems',
#  372: 'Social Network Enhancement for Non-formal Learning',
#  373: 'The Learning Object Triangle',
#  374: 'Agent-based interaction protocols and topologies for manufacturing task allocation',
#  375: 'A Recommendation Cascade for e-learning',
#  376: 'Hybrid P2P Architecture for Transaction Management',
#  377: 'Hybrid Profiling in Information Retrieval',
#  378: 'A new agents-based model for dynamic job allocation in manufacturing shopfloors',
#  379: 'An optimized approach for storing and accessing small files on cloud storage',
#  380: 'A service-oriented architecture for robust e-voting',
#  381: 'File management in a mobile DHT-based P2P environment',
#  382: 'The Impact of Modes of Mediation on the Web Retrieval Process',
#  383: 'Model interoperability via model driven development',
#  384: 'Robust e-Voting Composition',
#  385: 'An architecture for grid-enabled distributed simulation',
#  386: 'Stateless data concealment for distributed systems',
#  387: 'A timed automata approach to QoS resolution',
#  388: 'eLearning content provision',
#  389: 'Implementation of a proactive load sharing scheme',
#  390: 'Multiple evolutionary agents for decision support',
#  391: 'Transaction oriented engineering design and formal specification: a multi-agent approach',
#  392: 'An agent-based approach to engineering design',
#  393: 'Data mining and serial documents',
#  394: 'HiSQL: A front-end Query System for Historical Databases',
#  395: 'Assessing Risks in Dairy Supply Chain Systems: A System Dynamics Approach',
#  396: 'A Critical Overview of Food Supply Chain Risk Management',
#  397: 'Sustainable Supply Chain Management in Iranian Manufacturing Companies',
#  398: 'Contextualising sustainability reporting in host communities: An insight from a mining subsidiary in Ghana',
#  399: 'Formal and informal sustainability reporting: an insight from a mining company’s subsidiary in Ghana',
#  400: 'Pedagogical Approaches to Entrepreneurship Education in UK: Team Academy versus Traditional Models',
#  401: 'Trust in Nigerian SMEs exporting to West African Market',
#  402: "We Know their House, Family and Workplace: Trust in Entrepreneurs' Trade Credit Relationships in Weak Institutions ",
#  403: 'Diaspora entrepreneurs’ push and pull institutional factors for investing in Africa: Insights from African returnees from the United Kingdom',
#  404: 'Getting Personal: the issues of trust and distrust in small and medium-sized enterprises in Nigeria',
#  405: 'In courts we dont trust: Institutional Framework in the context of developing economy',
#  406: 'HRM operational models and practices to enable strategic agility in PBOs: Managing paradoxical tensions',
#  407: 'Linking HRM to organisational agility in project-based organisations: An Agile-Oriented HRM perspective: organisational agility, Agility-Oriented HRM , Strategic Agility',
#  408: 'Comparing sustainability disclosures on corporate websites: A case study of Newmont Mining Corporation’s plant sites in Ghana',
#  409: 'Factors influencing school building construction projects abandonment',
#  410: 'Identifying Employee Engagement Practices to Facilitate Organisational Agility: Evidence from a Qualitative Research Conducted in the UK',
#  411: 'Riding the wave: Female Entrepreneurship in Pakistan',
#  412: 'The Role of Human Resource Management in Achieving Organisational Agility: Strategic Agility, Organisational Agility, Agile HRM, Workforce agility',
#  413: 'HR Contributions in Organisational Agility: New Roles and Mission',
#  414: 'Trust, Institutions and Managing Entrepreneurial Relationships in Africa: An SME Perspective',
#  415: 'Emerging Human Resource Practices to Support Organisational Agility',
#  416: 'Trust and Distrust in Nigerian Supply Chain Relationships',
#  417: '“Impact Assessment Study of the Primary Care Asylum Service”',
#  418: 'All we need is trust: Trust in West African cross border networks',
#  419: 'Corruption as a source of government project failure in developing countries: Evidence from Ghana',
#  420: 'Preparing Freelancers of the Future: A teaching case study',
#  421: 'Assessing the impact of corruption on the management of Ghana government educational infrastructural projects',
#  422: 'Entrepreneurship Education and Employability: Insights from UK',
#  423: 'The Role of Technology Innovation in Shaping the Student Learning Experience in Higher Education',
#  424: 'Trust at the heart of the issue: Towards the building of trust based organization',
#  425: 'Entrepreneurship in the Music Industry of three Sub Saharan African Countries',
#  426: 'Interorganizational trust violations and repairs in uncertain environments: cultural context and power relations shaping Ghanaian exporting SMEs',
#  427: 'Norms and trust-shaping relationships among food- exporting SMEs in Ghana',
#  428: '‘We don’t deal with courts’: cooperation and alternative institutions shaping exporting relationships of SMEs in Ghana',
#  429: 'Legitimizing Dishonesty in Organizations: A Survey of Managers in Four Sub-Sahara African Countries',
#  430: 'Trust in exporting relationships: The case of Ghana',
#  431: 'Interorganizational trust violations and repairs in a weak legal environment: the case of Ghanaian exporting SMEs',
#  432: 'Detergent-Free Membrane Protein Purification Using SMA Polymer',
#  433: 'Membrane Protein Production in the Yeast P. pastoris',
#  434: 'Calcium: Calcitonin gene-related peptide and adrenomedullin receptors',
#  435: 'The immune receptor FcR chain mediates CD36-oxidized low-density lipoprotein-induced platelet activation and thrombosis',
#  436: 'CD81 extracted in SMALP nanodiscs comprises two distinct protein populations within a lipid environment enriched with negatively charged headgroups',
#  437: 'Technology Legitimation and User Resistance: The NHS COVID-19 App',
#  438: 'Remote working has led to managers spying more on staff – here are three ways to curb it',
#  439: 'Information and Communication Technologies (ICTs) as Oppressors of Social Movements: A Power Perspective',
#  440: 'Oppression vs. liberation through digitisation',
#  441: 'The Digital Transformation of Social Movements: Is It Good to Be “Seen”?',
#  442: 'Revisiting leadership in information and communication technology (ICT)-enabled activism: A study of Egypt’s grassroots human rights groups',
#  443: 'Paradoxes of Visibility in Activism',
#  444: 'Applications of unsaturated polyester resins in asphalt pavements',
#  445: 'Coupling Simulation of Human-Environmental Safety Risk Factors in Metro Construction –: a Case Study of Rongjiazhai Station at Xi’an Metro Line 5 in China',
#  446: "COVID-19 influence on commuters' attitude towards riding public buses for essential trips",
#  447: 'Effects of Chemical Stabilisation of Eggshells-Lime and Fly-Ash-Cement on the Structural Strength of Subgrade Soil in Rural Roads',
#  448: 'Phenolic Foams: The Insulating Materials to Reduce the Frost Penetration, Skidding, and Flooding Risk of Road and Airfield Pavements',
#  449: 'The Aspiration for Happy Train Journey: Commuters’ Perception of the Quality of Intercity Rail Services',
#  450: 'Use of Reclaimed Asphalt Pavement and Recycled Waste Glass as Partial Aggregate Replacements in Concrete Pavements',
#  451: 'Backpropagation Algorithms of Neural Networks to construct the Railway Track Deterioration Model',
#  452: 'Evaluating the Microstructure of Photoluminescent Concrete Pavement Containing Strontium-Aluminate, Acrylic and Recycled Waste Glass',
#  453: 'Exploring the travel behavior changes caused by the COVID-19 crisis: A case study for a developing country',
#  454: 'Impacts of low-density polyethylene (plastic Shopping bags) on structural performance and permeability of HMA mixtures',
#  455: 'Route Optimisation Programming for Emergency Vehicles Aftermath of Freight Train Accidents Involving Hazardous Materials',
#  456: 'Backpropagation – Artificial Neural Network (BP-ANN): Understanding gender characteristics of older driver accidents in West Midlands of United Kingdom',
#  457: 'Changing the colour of night on urban streets - LED vs. part-night lighting system',
#  458: 'Experimental feasibility study of using date palm oil as a bitumen Bio-Modifier in HMA pavement',
#  459: 'Impacts of Low-Density Polyethylene (Plastic Shopping Bags) on Structural Performance and Permeability of HMA Mixtures',
#  460: 'Machine Learning Algorithms for Rutting Modelling of Bituminous Pavements in West Midlands',
#  461: 'Resilience Assessment of Safety System at Subway Construction Sites Applying Analytic Network Process and Extension Cloud Models',
#  462: 'Towards Resilient Roads to Storm-Surge Flooding: Case Study of Bangladesh',
#  463: 'Effects of OASIS\u2060® phenolic foam on hydraulic behaviour of permeable pavement systems',
#  464: 'Optimal pavement management: Resilient roads in support of emergency response of cyclone affected coastal areas',
#  465: 'Multicultural Education in Civil Engineering: Planning and Transportation approach',
#  466: 'Regional Freight Movement and Its Impact on Air Quality: Simulation of Freight Traffic and Pavement Maintenance Operations',
#  467: 'Understanding Air Pollution from Induced Traffic during and after the Construction of a New Highway: Case Study of Highway 25 in Montreal',
#  468: 'Voluntary Risk Taking By Young Bicyclists: A Case Study of University Students at Montreal',
#  469: 'Backpropagation Neural Network to estimate pavement performance: Dealing with Measurement Errors',
#  470: 'Thornthwaite Moisture Index Modeling to Estimate the Implication of Climate Change on Pavement Deterioration',
#  471: 'Behaviour of Land prices in a Satellite Town of a Mega City',
#  472: 'Environmental Impact of the Induced Traffic from Highway 25 Extension Project',
#  473: 'Pavement management with dynamic traffic and artificial neural network: a case study of Montreal',
#  474: 'The Spatial Pattern of Sustainable Urban Development Indicator for the Montreal Urban Community',
#  475: 'The stochastic modeling of the turning decision by left-turning vehicles at a signalized intersection in a university campus',
#  476: 'Travel Demand Modeling To Simulate Traffic Loads for Pavement Deterioration Curves: Dealing With Aggregate Data at Urban And Regional Scales',
#  477: 'A Performance-Based Pavement Management System for the Road Network of Montreal City–a Conceptual Framework',
#  478: 'A performance-based Pavement Management System for the road network of Montreal city—a conceptual framework',
#  479: 'Climate Change Modeling and the Weather-Related Road Accidents',
#  480: 'Climate Change Modeling and the Weather-Related Road Accidents',
#  481: 'Discussion on Road Infrastructure Management Practices',
#  482: 'Rural road network in Bangladesh',
#  483: 'The carbon footprint of freight traffic and pavement treatments for interprovincial trade flows of Atlantic Canada',
#  484: 'The Multi-criteria based Pavement Management System for Regional Road Network of Atlantic Provinces of Canada',
#  485: 'The Pavement Performance Modeling: Deterministic vs Stochastic Approaches',
#  486: 'The Policy Implications of Banning Non-Motorized Vehicles (NMVs) from the Arterial Road of Dhaka City',
# ...
#  838: "Gender and Intergenerational Challenges to Women's Economic Empowerment Initiatives in Rwanda",
#  839: 'Investigation of baffle configuration effect on the performance of exhaust mufflers',
#  840: 'A cooperative covering problem under disruption considering backup coverage',
#  841: 'Social enterprise groups for South Sudanese refugee survivors of sexual and gender-based violence and torture living in refugee settlements in Northern Uganda.',
#  842: 'Nonlinear Optimization of Vehicle Safety Structures: Modeling of Structures Subjected to Large Deformations',
#  843: 'Mathematical modeling for a p-mobile hub location problem in a dynamic environment by a genetic algorithm',
#  844: 'The Female Genital Mutilation (FGM)- Migration Matrix: The case of the Arab League Region',
#  845: 'Validation of a Finite Element Human Model Throw Distance in Pedestrian Accident Scenarios',
#  846: 'Optimization of multi-response problems with continuous functional responses by considering dispersion effects',
#  847: 'Sexual and Gender-Based Violence and torture experiences of Sudanese refugees in Northern Uganda: health and justice responses',
#  848: 'A Design Methodology for Hydrogen Fuel Powered City Vehicles in Rear Impact Collisions',
#  849: 'Rebalancing static bike-sharing systems: A two-period two-commodity multi-depot mathematical model',
#  850: '"Should I stay, or should I go?": The experiences of, and choices available to women of South Asian heritage living in the UK when leaving a relationship of choice following intimate partner violence (IPV)',
#  851: 'Challenges and Opportunities for Improving the Safety of Lightweight Vehicles',
#  852: 'Robust solution for a minimax regret hub location problem in a fuzzy-stochastic environment',
#  853: 'South Sudanese Refugee Survivors of Sexual and Gender-Based Violence and Torture: Health and Justice Service Responses in Northern Uganda',
#  854: 'A Lighweighting Methodology Of A Trimaran High Speed Cruise Logistics Ferry (CLF)',
#  855: 'The bi-team orienteering problem with time window',
#  856: 'Transforming social norms to end FGM in the EU: An evaluation of the REPLACE Approach',
#  857: 'Injury prediction modelling in the ga design of a trimaran high speed Cruise Logistics Ferry (CLF)',
#  858: 'General form of a cooperative gradual maximal covering location problem',
#  859: 'Debating medicalisation of Female Genital Mutilation/Cutting (FGM/C): Learning from (policy) experiences across countries.',
#  860: 'New mathematical modeling for a location–routing–inventory problem in a multi-period closed-loop supply chain in a car industry',
#  861: "Evidence gathering to better understand the contribution of 'Celebrating Families' to family well-being: A case study from Tanzania",
#  862: 'An efficient network for disaster management: Model and solution',
#  863: "Understanding 'Celebrating Families'' contribution to family wellbeing: Key findings from Afghanistan, Myanmar and Tanzania",
#  864: 'A new approach to optimize a hub covering location problem with a queue estimation component using genetic programming',
#  865: "Understanding 'Celebrating Families' contribution to family wellbeing: Key findings from Tanzania",
#  866: 'Vehicle sharing system with fleet sizing and multi-transportation modes under allowable shortages: a hybrid metaheuristic approach',
#  867: 'FGM and population movements within and from the Arab Region',
#  868: 'A new mathematical model towards the integration of cell formation with operator assignment and inter-cell layout problems in a dynamic environment',
#  869: 'Gender and development in Africa: A 50 year journey from Women in Development to Gender Justice',
#  870: 'Opportunities for linking research to policy: Lessons learned from implementation research in sexual reproductive health within the ANSER Network',
#  871: 'Persistence and Resistance of Harmful Traditional Practices (HTPs) Perpetuated against Girls in Africa and Asia.',
#  872: 'Postpartum care for women with FGM: How good are the policies?',
#  873: 'The African HIV/AIDS epidemic: Is the end in sight?',
#  874: 'The New Orleans Mardi Gras: A mega-event with an intangible legacy of protest and resistance to social injustice and inequality.',
#  875: "The Tanzanian 'Cash Plus' Project: Process impact evaluation",
#  876: 'Engaging communities to implement behaviour change to end FGM in the EU: Lessons from the REPLACE Project',
#  877: 'The psychological and social impact of female genital mutilation: A holistic conceptual framework',
#  878: 'Working with African communities in the EU to end FGM: The REPLACE Approach',
#  879: 'Belief Systems Enforcing Female Genital Mutilation in Europe',
#  880: 'The REPLACE Approach: supporting Communities to end FGM in the EU. A Toolkit',
#  881: 'The REPLACE Approach: supporting Communities to end FGM in the EU. Community Handbook',
#  882: 'Exploring cultural connectedness in the sustainability of rural community tourism development in Jamaica: ORTE2014',
#  883: 'Female genital cutting: crossing borders',
#  884: "From 'health inequality' to 'health inequity': The move to a moral paradigm in global health disparity",
#  885: 'The beginning of the end? The global HIV/AIDS pandemic',
#  886: 'The Applicability of Behaviour Change in Intervention Programmes Targeted at Ending Female Genital Mutilation in the EU: Integrating Social Cognitive and Community Level Approaches',
#  887: 'HIV/AIDS and development',
#  888: 'Pilot toolkit for replacing approaches to ending FGM in the EU : implementing behaviour change with practising communities',
#  889: 'AIDS: act aware (editorial)',
#  890: 'HIV/AIDS and reaching migrant communities',
#  891: 'HIV/AIDS – a twenty-five year rollercoaster',
#  892: 'Human Immunodeficiency Virus (HIV) and migrant "risk environments". The case of the Ethiopian and Eritrean immigrant community in the West Midlands of the UK',
#  893: 'The Securitisation of HIV/AIDS, global health security and the rise of bio-politics',
#  894: 'Health inequalities',
#  895: 'Rangeland as a common property resource: contrasting insights from communal areas of central Eastern Cape Province, South Africa',
#  896: 'Too little too late: responses to the HIV/AIDS epidemics in sub-Saharan Africa',
#  897: 'From farm to supermarket: the trade in fresh horticultural produce from sub-Saharan Africa to the United Kingdom',
#  898: 'Rangeland management in communal areas of Central Eastern Cape province, South Africa: a study of two contrasting cases',
#  899: 'High-speed density measurement for LNG and other cryogenic fluids using electrical capacitance tomography',
#  900: 'Using single-sensor hot-wire anemometry for velocity measurements in confined swirling flows',
#  901: 'Organic certification and the UK market: organic import from developing countries',
#  902: 'The Effect of Swirl on the Flow Uniformity in Automotive Exhaust Catalysts',
#  903: 'Simulation of thermal comfort conditions of an air-conditioned cafeteria in the tropics',
#  904: 'Assessment of energy saving potentials for protected spaces in commercial buildings',
#  905: 'Adapting visual methods: action research with Kampala street children.',
#  906: 'Ownership, ontology and the contemporary dance commons',
#  907: 'Coming Together by Moving Apart: Contemporary dance scores and communities during the Covid-19 pandemic',
#  908: 'Dancing Right(s): Dance, Disability and Legal Empowerment in Post-War Sri Lanka',
#  909: 'Editorial: On (Un)Knowns',
#  910: 'Digital Aptitude: Finding the right questions for dance studies',
#  911: 'Dance, disability and performance in north and east Sri Lanka: evaluating audience responses',
#  912: 'Digital Dance',
#  913: 'Exchanging, Moving, Translating: thoughts on dance and disability',
#  914: 'Performance and the Partial',
#  915: 'Projects, Precarity and the Ontology of Dance Works',
#  916: 'A World of Muscle, Bone & Organs: Research and Scholarship in Dance',
#  917: 'Choreographic Knowledge and Aesthetic Empiricism',
#  918: 'Dance, Disability and Law: InVisible Difference',
#  919: "Dance's Political Imaginaries",
#  920: 'Performing Process: Sharing Dance and Choreographic Practice',
#  921: 'Preservation and Paradox: Choreographic Authorship in the Digital Sphere',
#  922: 'Running, Resistance and Recollection: A conversation with ourselves through time',
#  923: 'Screendance Self/portraits',
#  924: 'The Values of Leftovers in Dance Research',
#  925: 'Work(s) and (Non)production in Contemporary Movement Practices',
#  926: 'Affective Traces in Virtual Spaces: Annotation and Emerging Dance Scores',
#  927: 'Inscribing Work and Process: The Ontological Implications of Virtual Scoring Practices for Dance',
#  928: 'Scoring Choreographic Poetics',
#  929: 'Scoring Choreography: Process and Bodies in Digital Forms',
#  930: 'Digital Instances: Instantiating Dance On Screen',
#  931: 'Scoring Dance',
#  932: 'Creative Computing and the Re-Configuration of Dance Ontology',
#  933: 'Transforming Land, Transforming Lives: Greening Innovation and Urban Agriculture in the Context of Forced Displacement',
#  934: 'Refugee Camp Food Production: The Case of Nakivale Refugee Settlement in Uganda.',
#  935: 'Dance on the Internet: An Ontological Investigation',
#  936: 'Edited Realities',
#  937: 'Youth Workers’ experiences of spirituality and the impact it has on practice: An Interpretative Phenomenological Analysis',
#  938: 'Youth Workers Experiences of spirituality: An Interpretative Phenomenological Analysis’',
#  939: 'Youth Work about death and dying',
#  940: 'Does spirituality impact on Youth Work practice: Phase One Youth Workers experiences of Youth Work practice’',
#  941: 'Researching Spirituality with Youth Workers: My journey so far...',
#  942: 'Youth work with young people who are dying?',
#  943: "Young People's Spirituality",
#  944: "How can I improve my understanding of young people's spirituality? - An Action Research Project",
#  945: 'A Systematic Review of In-Vehicle Physiological Indices and Sensor Technology for Driver Mental Workload Monitoring',
#  946: 'External Human–Machine Interfaces for Automated Vehicles in Shared Spaces:  A Review of the Human–Computer Interaction Literature',
#  947: 'Novel Radar based In-Vehicle Occupant Detection Using Convolutional Neural Networks',
#  948: 'The notorious B.I.T: The effects of a ransomware and a screen failure on distraction in automated driving',
#  949: 'Evaluation of CMIP6 model performances in simulating fire weather spatiotemporal variability on global and regional scales',
#  950: 'Under pressure: Effect of a ransomware and a screen failure on trust and driving performance in an automated car simulation',
#  951: 'The April 2021 Cape Town wildfire: has anthropogenic climate change altered the likelihood of extreme fire weather?',
#  952: 'A global view of observed changes in fire weather extremes: uncertainties and attribution to climate change.',
#  953: 'Using fNIRS to Verify Trust in Highly Automated Driving',
#  954: 'Future orbiting and in-situ exploration of Venus: Mount Etna as terrestrial analogue.',
#  955: 'Designing Better Public Transport: Understanding Mode Choice Preferences Following the COVID-19 Pandemic',
#  956: 'Idunn Mons as the landing site of the Venera-D mission: scientific relevance and possible operational tests on Mount Etna.',
#  957: 'Determining the Social, Economic, Political and Technical Factors Significant to the Success of Dynamic Wireless Charging Systems through a Process of Stakeholder Engagement',
#  958: 'The first evaluation of the FY-3D/MERSI-2 sensor’s thermal infrared capabilities for deriving land surface temperature in volcanic regions: a case study of Mount Etna',
#  959: 'Driver State Monitoring: Manipulating Reliability Expectations in Simulated Automated Driving Scenarios',
#  960: 'The geologically recent areas as one key target for identifying active volcanism on Venus.',
#  961: 'How System Failures and Ransomwares Affect Drivers’ Trust and Attitudes in an Automated Car? A Simulator Study',
#  962: 'The Impact of Tree Planting on Infiltration Dependent on Tree Proximity and Maturity at a Clay Site in Warwickshire, England',
#  963: 'Physiological Measures of Risk Perception in Highly Automated Driving',
#  964: 'The Potential to Address Disease Vectors in Favelas in Brazil Using Sustainable Drainage Systems: Zika, Drainage and Greywater Management',
#  965: 'Understanding Drivers’ Trust After Software Malfunctions and Cyber Intrusions of Digital Displays in Automated Cars',
#  966: 'Underwater volcanoes: how ocean colour changes can signal an imminent eruption',
#  967: "Urban air mobility infrastructure design: Using virtual reality to capture user experience within the world's first urban airport",
#  968: 'Were meteorological conditions related to the 2020 Siberia wildfires made more likely by anthropogenic climate change?',
#  969: 'Using Glance Behaviour to Inform the Design of Adaptive HMI for Partially Automated Vehicles',
#  970: 'Groundwater Level Variations in relation to Volcanic and Seismic Events. New Insights on Mt. Etna, Southern Italy.',
#  971: 'Transformative Practice as a Learning Approach for Industrial Designers',
#  972: 'Design Education and non-EU students: shifts in teaching practice',
#  973: 'Although Autonomous Cars Are Not Yet Manufactured, Their Acceptance Already Is',
#  974: 'Modelling the Hydrological Effects of Woodland Planting on Infiltration and Peak Discharge Using HEC-HMS',
#  975: 'WHEEL OF DESIGN – REFLECTIVE ALIGNMENT OF DESIGN SKILLS WITH ASPIRATIONS',
#  976: 'English Corner: Fostering International Student Collaboration Through E-Learning Technologies',
#  977: 'Design Education as a Passport to Professional Practice, EPDE 2010 - When Design Education and Design Research Meet',
#  978: 'A new perspective on personas and customer journey maps: Proposing systemic UX',
#  979: 'Modelling the hydrological effects of woodland planting on infiltration and site discharge throughout the winter months using HEC-HMS',
#  980: 'Developing a Pedagogic Framework for Product and Automotive Design',
#  981: 'Visual Creativity and the Threshold of Uncertainty in Product and Automotive Design',
#  982: 'A novel method for reducing motion sickness susceptibility through training visuospatial ability – A two-part study',
#  983: 'Spatio-temporal surface temperature variations detected by satellite thermal infrared images at Merapi volcano, Indonesia',
#  984: 'Broadening Industry Perspectives of Vehicle Telematics Application through Virtual Learning Environments',
#  985: 'Broadening the Boundaries of Design Communication through e-Portfolio Tools',
#  986: 'A simulation study of platooning AV fleet service in shared urban environments with uncertainties',
#  987: 'Grounded aircraft could make weather forecasts less reliable',
#  988: 'Threshold concepts and the transport and product design curriculum: reports of research in progress',
#  989: 'Can we talk? How a talking agent can improve human autonomy team performance',
#  990: 'Holocene coastal change at Luce Bay, South West Scotland',
#  991: 'Editorial Mechatronics as an Enabler for Intelligent Transportation Systems',
#  992: 'Modelling the Role of SuDS Management Trains in Minimising Flood Risk, Using MicroDrainage',
#  993: 'Effect of cognitive load on drivers’ State and task performance during automated driving: Introducing a novel method for determining stabilisation time following take-over of control',
#  994: 'The co-incidence of earthquakes and volcanoes: assessing global volcanic radiant flux responses to earthquakes in the 21st century',
#  995: 'Exploring the utility of EDA and skin temperature as individual physiological correlates of motion sickness',
#  996: 'The potential of satellite remote sensing for monitoring the onset of volcanic activity on Taipei’s doorstep',
#  997: 'GNSS Vulnerabilities and Existing Solutions: A Review of the Literature',
#  998: 'Can one earthquake cause a cascade of more',
#  999: 'Improving productivity through servitization and digital transformation',
#  1000: 'Application of thermal remote sensing to the observation of natural hazards',
#  ...}

# %%
list(corpus_dict.values())

# %%
def text_preprocessor(corpus_dict):
    temp = {}
    translator  = str.maketrans('', '', string.punctuation)
    for kee in corpus_dict:
        corpus_dict[kee] = corpus_dict[kee].translate(translator)  
        
        tokens = word_tokenize(corpus_dict[kee])
        
        stop_words = set(stopwords.words('english'))
        filtered = [word for word in tokens if word.casefold() not in stop_words]
        
        temp[kee] = filtered
        
    return temp

clean_tokenized_corpus = text_preprocessor(corpus_dict)

# %%
clean_tokenized_corpus

# %%
inverted_index = {}

# Iterate over each document
for doc_id, words in clean_tokenized_corpus.items():
    # Iterate over each word in the document
    for word in words:
        # If the word is already in the posting list, add the current document ID to its set of IDs
        if word in inverted_index:
            inverted_index[word].add(doc_id)
        # If the word is not in the posting list, create a new key-value pair with the word and the set containing the current document ID
        else:
            inverted_index[word] = {doc_id}

sorted_inverted_index = {word: sorted(doc_ids) for word, doc_ids in sorted(inverted_index.items())}

# Print the posting list
for word, doc_ids in sorted_inverted_index.items():
    print(f"{word}: {doc_ids}")

# %%
len(sorted_inverted_index['00'])

# %%
# Calculate the TF-IDF scores for each term in each document
tfidf_scores = {}
for term, doc_ids in sorted_inverted_index.items():
    idf = math.log(len(corpus_dict) / len(doc_ids))  # total no. of docs / doc freq of term 't'
    for doc_id in doc_ids:
        tf = 1 + math.log(len(sorted_inverted_index[term]))  # Calculate TF
        tfidf_scores[(term, doc_id)] = tf * idf  # Calculate TF-IDF

# %%
tfidf_scores

# %%
tfidf_scores.get(('00', 5069), 0)

# %%
query = "obesity in kids"

query_terms = query.split()
query_vector = [tfidf_scores.get((term, 0), 0) for term in query_terms]

# %%
query_vector

# %%
similarities = {}
for doc_id in range(1, len(corpus_dict)):  # Assuming there are 4 documents with IDs 1, 2, 3, 4
    doc_vector = [tfidf_scores.get((term, doc_id), 0) for term in query_terms]
    dot_product = sum(x * y for x, y in zip(query_vector, doc_vector))
    query_norm = math.sqrt(sum(x ** 2 for x in query_vector))
    doc_norm = math.sqrt(sum(x ** 2 for x in doc_vector))
    similarity = dot_product / (query_norm * doc_norm)
    similarities[doc_id] = similarity

# Sort documents by cosine similarity
sorted_documents = sorted(similarities.items(), key=lambda x: x[1], reverse=True)

# Print the sorted documents
print("Search Results:")
for doc_id, similarity in sorted_documents:
    print(f"Document {doc_id}: Similarity = {similarity}")
